# %% [markdown]
# <a href="https://colab.research.google.com/github/depthgr8/pythonprograms/blob/main/Pythonbasics.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open this notebook in Colaboratory"/></a>

# %%
a = 'Deepak'
b = 5
a
print(type(a))
print(a+str(b))
# Out:
# 'Deepak'

# %%
fruits = ['Guava', 'Apple', 'Pineapple']
# print(fruits[0])

for i in fruits:
    print(i)

print(i)
if (i == 'Pineapple'):
    print("Current fruit value is = ",i)
# Out:
# Guava
# Apple
# Pineapple
# Pineapple
